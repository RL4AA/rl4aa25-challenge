# %% [markdown]
# # **RL4AA'25 Challenge Part 2:** Option RL
#
# In this notebook you can solve the RL challenge by training your own RL agent. If you are a beginner in RL, we recommend you stick the with provided code using the PPO implementation from _Stable Baselines3_, and try to tune the hyperparameters of both the environment and the PPO algorithm through the `config` dictionary. If you are more experienced, feel free to change the algorithm or move to a completely different RL library altogether, provided you believe that it will help you solve the challenge.
#
# ## IMPORTANT: PLEASE READ BEFORE RUNNING THE NOTEBOOK
#
# Training a good RL agent can take a lot of time. The task in this challenge was designed such that 500,000 steps should be enough to solve it well. (Though you can train longer if you think you can do better. 😉) On a Mac with an Apple-made SoC, such a training should be doable in about 10 minutes. It may take longer on other machines, expect at least 30 minutes on a recent Windows or Linux laptop.
#
# **More importantly** this training can use a considerable amount of RAM. In the worst case, this can also cause other applications to crash when you start training. So please make sure you have nothing unsaved open on your computer before you start training, and that you follow the instructions on setting `n_envs` correctly. When in doubt use a lower number.
#
# The following code also uses (_Weight & Biases_)[https://wandb.ai] to log the training. We recommend you create a free account there and check out the results to better understand what is happening during training. If you don't want to use _Weight & Biases_, run `wandb disabled` in a terminal in the root of this repository. You can then still use Tensorboard to visualise the training progress by running `tensorboard --logdir log/` in a terminal in the root of this repository.

# %%
from functools import partial
from pathlib import Path

import numpy as np
import torch.nn as nn
from rl_zoo3 import linear_schedule
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from wandb.integration.sb3 import WandbCallback

import wandb
from src.eval import Study
from src.eval.eval_rl_v3_sim import evaluate_policy
from src.train.ea_ppo import make_env
from src.utils import load_config, save_config

# %% [markdown]
# ## Configure the RL training with the PPO algorithm from _Stable Baselines3_
#
# Below you find the `config` dictionary that contains all the hyperparameters for the PPO algorithm and the environment. You can change the values to optimise the training of your agent.
#
# You may also modify the `_get_reward` method of the environment to change the reward function. It can be found in [`src/environments/ea.py` line 338](src/environments/ea.py:338).

# %%
config = {
    # ===== Environment parameters =====
    # You may change any of these. However, be aware that in the evaluation, some of
    # these parameters are set to different values, regardless of what you set in
    # the training. It may or may not make sense to change them here. You will just have
    # to find out what happens yourself.
    # ---------------------
    # Choose weather actions set magnet settings directly (`"direct"`) or change magnet
    # settings (`"delta"`)
    "action_mode": "delta",
    # Maximum allowed quadrupole setting. The real quadrupoles can be set from -72 to
    # 72. These limits are imposed by the power supplies, but are unreasonably high to
    # the task at hand. It might therefore make sense to choose a lower value.
    "max_quad_setting": 30.0,
    # Limit of by how much quadrupole settings may be changed when `action_mode` is set
    # to `"delta"`. This parameter is ignored when `action_mode` is set to `"direct"`.
    "max_quad_delta": 30.0,
    # Limit of by how much steerer settings may be changed when `action_mode` is set to
    # `"delta"`. This parameter is ignored when `action_mode` is set to `"direct"`.
    "max_steerer_delta": 6.1782e-3,
    # Magnet initialisation on `reset`. Set to `None` for magnets to stay at their
    # current settings, `"random"` to be set to random settings or an array of five
    # values to set them to a constant value.
    "magnet_init_mode": np.array([10.0, -10.0, 0.0, 10.0, 0.0]),
    # Setting for incoming beam parameters on reset. Can be `"random"` to generate
    # random parameters or an array of 11 values to set them to a constant value.
    "incoming_mode": "random",
    # Setting for misalignment of magnets and the diagnostic screen on reset. Can be
    # `"random"` to generate random misalignments or an array of 8 values to set them to
    # a constant value.
    # NOTE: This is fixed to `"random"` in the evaluation.
    "misalignment_mode": "random",
    # Maximum misalignment of magnets and the diagnostic screen in meters when
    # `misalignment_mode` is set to `"random"`. This parameter is ignored when
    # `misalignment_mode` is set to a constant value.
    # NOTE: This is fixed to `5e-4` in the evaluation.
    "max_misalignment": 5e-4,
    # If `True`, the screen is assumed to be finite and false false beam parameters are
    # returned when the beam is not on the screen. The false beam parameters are
    # estimates of what would be measured on the real screen as a result of the camera
    # vignetting when no beam is visible.
    # NOTE: That these false beam parameters would always be returned and therefore also
    # be used for the reward computation.
    # NOTE: This is fixed to `True` in the evaluation.`
    "simulate_finite_screen": False,
    # Setting of target beam on `reset`. Set to "random" to generate a random target
    # beam or to an array of four values to set it to a constant value.
    # NOTE: This is fixed to `"np.zeros(4)"` in the evaluation. You can try training on
    # random, but this is significantly harder and out of scope for this challenge.
    "target_beam_mode": np.zeros(4),
    # If `True`, magnet settings are clipped to their allowed ranges after each step.
    "clip_magnets": True,
    # ===== Wrapper parameters =====
    # Number of observations into the past that are passed to the policy. A value of 1
    # means that only the current observation is passed.
    "frame_stack": 1,
    # Whether to scale the observations from their physical ranges to a range of [-1, 1]
    # before passing them to the policy.
    "normalize_observation": True,
    # Whether to expect the policy to output actions in the range of [-1, 1] (`True`) or
    # in the physical range of the actions (`False`).
    "rescale_action": True,
    # NOTE: Please do not change the `target_threshold` parameter.
    "target_threshold": None,
    # Number of steps per episode allowed during training before the environment is
    # reset.
    # NOTE: In the evaluation policies will be run for an arbitrary number of steps.
    "max_episode_steps": 50,
    # ===== RL algorithm parameters =====
    # Please refer to the Stable Baselines3 documentation for the meaning of these
    # parameters:
    #   https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#parameters
    # NOTE: Good settings of `n_steps` and `n_envs` depend a lot on your hardware, and
    # they depend on each other. We recommend using one of the following options based
    # on your hardware:
    #   - 32 GB RAM or more: `n_envs=40`, `n_steps=64`
    #   - 16 GB RAM: `n_envs=20`, `n_steps=128`
    #   - 8 GB RAM: `n_envs=10`, `n_steps=256`
    # USING TOO LARGE VALUES MAY CAUSE OTHER APPLICATIONS TO CRASH WITHOUT WARNING!!!
    "batch_size": 64,
    "learning_rate": 0.0003,
    "lr_schedule": "constant",  # Can be "constant" or "linear"
    "gamma": 0.99,
    "n_envs": 40,
    "n_steps": 64,
    "ent_coef": 0.0,
    "n_epochs": 10,
    "gae_lambda": 0.95,
    "clip_range": 0.2,
    "clip_range_vf": None,  # None,
    "vf_coef": 0.5,
    "max_grad_norm": 0.5,
    "use_sde": False,
    "sde_sample_freq": -1,
    "target_kl": None,
    "total_timesteps": 500_000,
    # ===== Policy parameters =====
    # Size of the policy network. Can be "small" or "medium". Alternatively define
    # custom layer sizes below.
    "net_arch": "small",
    # Activation function of the policy network. Can be "Tanh", "ReLU" or "GELU".
    "activation_fn": "Tanh",
    # Whether or not to use orthogonal initialisation of the policy network weights.
    "ortho_init": True,  # True, False
    # Initial value of the log standard deviation of the policy network output.
    "log_std_init": 0.0,
    # ===== SB3 configuration =====
    # PyTorch device used for training. You should probably leave this at "auto".
    "sb3_device": "auto",
    # Setting for how parallel environments for training rollouts handled. Set to
    # "dummy" for parallel environments to be called in a for loop on a single process,
    # or to "subproc" for parallel environments running in separate processes.
    "vec_env": "subproc",
}

# %% [markdown]
# ## Train your RL agent
#
# Below is the code for training the RL agent with the PPO algorithm as implemented in _Stable Baselines3_. You probably shouldn't change this cell unless you know what you are doing. If you want to use a different algorithm, you will need to change the code below.

# %%
# Setup wandb
wandb.init(
    project="rl4aa25-challenge",
    sync_tensorboard=True,
    monitor_gym=True,
    config=config,
    dir=".wandb",
)
config = dict(wandb.config)
config["run_name"] = wandb.run.name

# Setup vecorised environments for training and evaluation
assert config["vec_env"] in ["dummy", "subproc"]
vec_env = (
    DummyVecEnv([partial(make_env, config) for _ in range(config["n_envs"])])
    if config["vec_env"] == "dummy"
    else SubprocVecEnv([partial(make_env, config) for _ in range(config["n_envs"])])
)
eval_vec_env = DummyVecEnv(
    [partial(make_env, config, plot_episode=True, log_task_statistics=True)]
)

# Setup learning rate schedule if needed
if config["lr_schedule"] == "linear":
    config["learning_rate"] = linear_schedule(config["learning_rate"])

# Setup RL training algorithm
model = PPO(
    "MlpPolicy",
    vec_env,
    learning_rate=config["learning_rate"],
    n_steps=config["n_steps"],
    batch_size=config["batch_size"],
    n_epochs=config["n_epochs"],
    gamma=config["gamma"],
    gae_lambda=config["gae_lambda"],
    clip_range=config["clip_range"],
    clip_range_vf=config["clip_range_vf"],
    ent_coef=config["ent_coef"],
    vf_coef=config["vf_coef"],
    max_grad_norm=config["max_grad_norm"],
    use_sde=config["use_sde"],
    sde_sample_freq=config["sde_sample_freq"],
    target_kl=config["target_kl"],
    policy_kwargs={
        "activation_fn": getattr(nn, config["activation_fn"]),
        "net_arch": {  # From rl_zoo3
            "small": {"pi": [64, 64], "vf": [64, 64]},
            "medium": {"pi": [256, 256], "vf": [256, 256]},
        }[config["net_arch"]],
        "ortho_init": config["ortho_init"],
        "log_std_init": config["log_std_init"],
    },
    device=config["sb3_device"],
    tensorboard_log=f"log/{config['run_name']}",
    verbose=1,
)

# Setup callbacks for evaluation and logging
eval_callback = EvalCallback(eval_vec_env, eval_freq=1_000, n_eval_episodes=5)
wandb_callback = WandbCallback()

# Train the model
model.learn(
    total_timesteps=config["total_timesteps"],
    callback=[eval_callback, wandb_callback],
)

# Save the model and associated configuration
model.save(f"models/ea/ppo/{wandb.run.name}/model")
save_config(config, f"models/ea/ppo/{wandb.run.name}/config")

# Cleanup environments
vec_env.close()
eval_vec_env.close()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#   ········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /Users/simon.hirlaender/.netrc
# wandb: Currently logged in as: sarl-ida-plus (sarl-ida-plus-sarl-ida-lab-team) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path .wandb/wandb/ wasn't writable, using system temp directory.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/var/folders/kd/ts8cjkj92cb51mz6vfv08mnm0000gn/T/wandb/run-20250331_152400-3ccz8wen</code>
# Syncing run <strong><a href='https://wandb.ai/sarl-ida-plus-sarl-ida-lab-team/rl4aa25-challenge/runs/3ccz8wen' target="_blank">fanciful-universe-1</a></strong> to <a href='https://wandb.ai/sarl-ida-plus-sarl-ida-lab-team/rl4aa25-challenge' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sarl-ida-plus-sarl-ida-lab-team/rl4aa25-challenge' target="_blank">https://wandb.ai/sarl-ida-plus-sarl-ida-lab-team/rl4aa25-challenge</a>
#  View run at <a href='https://wandb.ai/sarl-ida-plus-sarl-ida-lab-team/rl4aa25-challenge/runs/3ccz8wen' target="_blank">https://wandb.ai/sarl-ida-plus-sarl-ida-lab-team/rl4aa25-challenge/runs/3ccz8wen</a>
# Using cpu device
# Logging to log/fanciful-universe-1/PPO_1
# /opt/anaconda3/envs/rl4aa25-challenge/lib/python3.11/site-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x3217f4b10> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x174673110>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 1965     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2560     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2452        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.009669061 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | -0.00967    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.68        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.998       |
# |    value_loss           | 55.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2706        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.011088847 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | -0.00127    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.75        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00704    |
# |    std                  | 0.998       |
# |    value_loss           | 31.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2824        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009782118 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | 0.0406      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.25        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00612    |
# |    std                  | 1           |
# |    value_loss           | 30.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2933        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.010743606 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.12       |
# |    explained_variance   | -0.0122     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.75        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00607    |
# |    std                  | 1.01        |
# |    value_loss           | 29.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2970        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.010758182 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.00141     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.15        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00434    |
# |    std                  | 1.01        |
# |    value_loss           | 20.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 3020        |
# |    iterations           | 7           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.008233533 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | -0.0229     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.25        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00509    |
# |    std                  | 1.01        |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 3036        |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009316625 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.15       |
# |    explained_variance   | 0.000108    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.28        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00546    |
# |    std                  | 1.02        |
# |    value_loss           | 13.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 3066         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 23040        |
# | train/                  |              |
# |    approx_kl            | 0.0071531096 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.17        |
# |    explained_variance   | 0.000216     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00622     |
# |    std                  | 1.01         |
# |    value_loss           | 10.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 3073        |
# |    iterations           | 10          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.010011745 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.15       |
# |    explained_variance   | -0.00117    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0074     |
# |    std                  | 1.01        |
# |    value_loss           | 6.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 3096        |
# |    iterations           | 11          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.009465834 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.16       |
# |    explained_variance   | 0.00064     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00854    |
# |    std                  | 1.02        |
# |    value_loss           | 4.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 3081        |
# |    iterations           | 12          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007798883 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.16       |
# |    explained_variance   | -0.000164   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 1.01        |
# |    value_loss           | 5.01        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 3103         |
# |    iterations           | 13           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 33280        |
# | train/                  |              |
# |    approx_kl            | 0.0075562126 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.13        |
# |    explained_variance   | -0.0163      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.994        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00725     |
# |    std                  | 1.01         |
# |    value_loss           | 3.33         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 3098        |
# |    iterations           | 14          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.009611593 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.15       |
# |    explained_variance   | 0.00077     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.682       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00902    |
# |    std                  | 1.01        |
# |    value_loss           | 2.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 3113        |
# |    iterations           | 15          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.008262177 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.14       |
# |    explained_variance   | -0.00549    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.654       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.01        |
# |    value_loss           | 1.98        |
# -----------------------------------------
# Eval num_timesteps=40000, episode_reward=50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | 50          |
# | time/                   |             |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.007889925 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | -0.00518    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.534       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00999    |
# |    std                  | 1           |
# |    value_loss           | 1.83        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 1806     |
# |    iterations      | 16       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 40960    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1856        |
# |    iterations           | 17          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 43520       |
# | train/                  |             |
# |    approx_kl            | 0.009191053 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.12       |
# |    explained_variance   | -0.00419    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.284       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 1.01        |
# |    value_loss           | 1.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1896        |
# |    iterations           | 18          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.010438545 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.14       |
# |    explained_variance   | 0.000546    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.256       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 1.01        |
# |    value_loss           | 0.808       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1941        |
# |    iterations           | 19          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 48640       |
# | train/                  |             |
# |    approx_kl            | 0.008457429 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | -0.000698   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.35        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 1.01        |
# |    value_loss           | 0.881       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1976        |
# |    iterations           | 20          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009507449 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.00057     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.225       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 1.01        |
# |    value_loss           | 0.636       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2013        |
# |    iterations           | 21          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 53760       |
# | train/                  |             |
# |    approx_kl            | 0.008571491 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.16       |
# |    explained_variance   | -0.00254    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 1.02        |
# |    value_loss           | 0.385       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2045        |
# |    iterations           | 22          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.009892163 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.16       |
# |    explained_variance   | -1.8e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 1.01        |
# |    value_loss           | 0.347       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2080        |
# |    iterations           | 23          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 58880       |
# | train/                  |             |
# |    approx_kl            | 0.008297486 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.15       |
# |    explained_variance   | -0.00262    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.1         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 1.01        |
# |    value_loss           | 0.369       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2108        |
# |    iterations           | 24          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008938992 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.00156     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0653      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 1.01        |
# |    value_loss           | 0.206       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2137        |
# |    iterations           | 25          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 64000       |
# | train/                  |             |
# |    approx_kl            | 0.009476499 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | 0.0135      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0416      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 1           |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2163        |
# |    iterations           | 26          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 66560       |
# | train/                  |             |
# |    approx_kl            | 0.010351354 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | -0.0401     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0794      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.995       |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2190        |
# |    iterations           | 27          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 69120       |
# | train/                  |             |
# |    approx_kl            | 0.008766265 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.04       |
# |    explained_variance   | 0.00059     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0166      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.987       |
# |    value_loss           | 0.126       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2211        |
# |    iterations           | 28          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010591703 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.99       |
# |    explained_variance   | -0.00421    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0133      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.974       |
# |    value_loss           | 0.0757      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2234        |
# |    iterations           | 29          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 74240       |
# | train/                  |             |
# |    approx_kl            | 0.010883361 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.98       |
# |    explained_variance   | 0.00582     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00741     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.982       |
# |    value_loss           | 0.0671      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2255        |
# |    iterations           | 30          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 76800       |
# | train/                  |             |
# |    approx_kl            | 0.009677475 |
# |    clip_fraction        | 0.0988      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.98       |
# |    explained_variance   | -0.00318    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00294     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.977       |
# |    value_loss           | 0.0771      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2278        |
# |    iterations           | 31          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 79360       |
# | train/                  |             |
# |    approx_kl            | 0.009400582 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.96       |
# |    explained_variance   | -0.00051    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00592     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.974       |
# |    value_loss           | 0.0457      |
# -----------------------------------------
# Eval num_timesteps=80000, episode_reward=50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | 50          |
# | time/                   |             |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.009766515 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.97       |
# |    explained_variance   | 0.00359     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00169     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.977       |
# |    value_loss           | 0.0311      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 1831     |
# |    iterations      | 32       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 81920    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1856        |
# |    iterations           | 33          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 84480       |
# | train/                  |             |
# |    approx_kl            | 0.009147868 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.94       |
# |    explained_variance   | -0.00419    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00156     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.966       |
# |    value_loss           | 0.0323      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 1878       |
# |    iterations           | 34         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 87040      |
# | train/                  |            |
# |    approx_kl            | 0.01053862 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.9       |
# |    explained_variance   | 0.00443    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0156    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.015     |
# |    std                  | 0.964      |
# |    value_loss           | 0.0301     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 1902         |
# |    iterations           | 35           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 89600        |
# | train/                  |              |
# |    approx_kl            | 0.0094383415 |
# |    clip_fraction        | 0.0927       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.89        |
# |    explained_variance   | -0.00982     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0052       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0136      |
# |    std                  | 0.961        |
# |    value_loss           | 0.0168       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1920        |
# |    iterations           | 36          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011587186 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.86       |
# |    explained_variance   | 0.00219     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0237     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.954       |
# |    value_loss           | 0.014       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1943        |
# |    iterations           | 37          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 94720       |
# | train/                  |             |
# |    approx_kl            | 0.010710243 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.83       |
# |    explained_variance   | 0.00262     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00513    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.947       |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1963        |
# |    iterations           | 38          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.011111456 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.8        |
# |    explained_variance   | -0.0188     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0353     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.942       |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1982        |
# |    iterations           | 39          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 99840       |
# | train/                  |             |
# |    approx_kl            | 0.010756073 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.77       |
# |    explained_variance   | 0.00224     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.937       |
# |    value_loss           | 0.00705     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2000        |
# |    iterations           | 40          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.009496076 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.74       |
# |    explained_variance   | -0.000975   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0384     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.928       |
# |    value_loss           | 0.00698     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2019        |
# |    iterations           | 41          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 104960      |
# | train/                  |             |
# |    approx_kl            | 0.009708473 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.72       |
# |    explained_variance   | 0.000304    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.93        |
# |    value_loss           | 0.00732     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2037        |
# |    iterations           | 42          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 107520      |
# | train/                  |             |
# |    approx_kl            | 0.007996162 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.71       |
# |    explained_variance   | -0.00612    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0107     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.926       |
# |    value_loss           | 0.00408     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2055        |
# |    iterations           | 43          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 110080      |
# | train/                  |             |
# |    approx_kl            | 0.010376655 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.69       |
# |    explained_variance   | 0.00667     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0296     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.924       |
# |    value_loss           | 0.00321     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2072        |
# |    iterations           | 44          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.009078935 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.69       |
# |    explained_variance   | -0.00046    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0353     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.923       |
# |    value_loss           | 0.00365     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2087        |
# |    iterations           | 45          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 115200      |
# | train/                  |             |
# |    approx_kl            | 0.011146864 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.69       |
# |    explained_variance   | 0.00485     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.925       |
# |    value_loss           | 0.00252     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 2101         |
# |    iterations           | 46           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 117760       |
# | train/                  |              |
# |    approx_kl            | 0.0106738135 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.69        |
# |    explained_variance   | 0.00353      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0185      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0167      |
# |    std                  | 0.921        |
# |    value_loss           | 0.00159      |
# ------------------------------------------
# Eval num_timesteps=120000, episode_reward=50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | 50          |
# | time/                   |             |
# |    total_timesteps      | 120000      |
# | train/                  |             |
# |    approx_kl            | 0.009278943 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.67       |
# |    explained_variance   | 0.000791    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.92        |
# |    value_loss           | 0.0015      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 1822     |
# |    iterations      | 47       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 120320   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 1839       |
# |    iterations           | 48         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.01000448 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.68      |
# |    explained_variance   | 0.00221    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.026     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0166    |
# |    std                  | 0.923      |
# |    value_loss           | 0.00167    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1855        |
# |    iterations           | 49          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 125440      |
# | train/                  |             |
# |    approx_kl            | 0.011923285 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.7        |
# |    explained_variance   | -0.0109     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0168     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.927       |
# |    value_loss           | 0.000947    |
# ...
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000158   |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.456       |
# |    value_loss           | 1.25e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1830        |
# |    iterations           | 181         |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 463360      |
# | train/                  |             |
# |    approx_kl            | 0.016412264 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.044       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.036      |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.457       |
# |    value_loss           | 1.49e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1834        |
# |    iterations           | 182         |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 465920      |
# | train/                  |             |
# |    approx_kl            | 0.014568721 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.0471      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00923    |
# |    std                  | 0.458       |
# |    value_loss           | 1.09e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1838        |
# |    iterations           | 183         |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 468480      |
# | train/                  |             |
# |    approx_kl            | 0.013595973 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.0273      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0298     |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.457       |
# |    value_loss           | 4.7e-07     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50        |
# |    ep_rew_mean          | 50        |
# | time/                   |           |
# |    fps                  | 1842      |
# |    iterations           | 184       |
# |    time_elapsed         | 255       |
# |    total_timesteps      | 471040    |
# | train/                  |           |
# |    approx_kl            | 0.0140888 |
# |    clip_fraction        | 0.191     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.13     |
# |    explained_variance   | 0.018     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00921  |
# |    n_updates            | 1830      |
# |    policy_gradient_loss | -0.0112   |
# |    std                  | 0.455     |
# |    value_loss           | 1.23e-07  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 1846       |
# |    iterations           | 185        |
# |    time_elapsed         | 256        |
# |    total_timesteps      | 473600     |
# | train/                  |            |
# |    approx_kl            | 0.01878956 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.0761     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0198    |
# |    n_updates            | 1840       |
# |    policy_gradient_loss | -0.0162    |
# |    std                  | 0.452      |
# |    value_loss           | 7.5e-07    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1850        |
# |    iterations           | 186         |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 476160      |
# | train/                  |             |
# |    approx_kl            | 0.015781691 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.028      |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.449       |
# |    value_loss           | 2.33e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1854        |
# |    iterations           | 187         |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 478720      |
# | train/                  |             |
# |    approx_kl            | 0.015132986 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | -0.0108     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0203     |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.446       |
# |    value_loss           | 1.47e-07    |
# -----------------------------------------
# Eval num_timesteps=480000, episode_reward=50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | 50          |
# | time/                   |             |
# |    total_timesteps      | 480000      |
# | train/                  |             |
# |    approx_kl            | 0.014704252 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.0208      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.03       |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.445       |
# |    value_loss           | 1.12e-07    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 1792     |
# |    iterations      | 188      |
# |    time_elapsed    | 268      |
# |    total_timesteps | 481280   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1796        |
# |    iterations           | 189         |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 483840      |
# | train/                  |             |
# |    approx_kl            | 0.020583984 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.000428    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0124     |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.441       |
# |    value_loss           | 1.46e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1800        |
# |    iterations           | 190         |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 486400      |
# | train/                  |             |
# |    approx_kl            | 0.016023345 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0431     |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.434       |
# |    value_loss           | 1.02e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1804        |
# |    iterations           | 191         |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 488960      |
# | train/                  |             |
# |    approx_kl            | 0.016797217 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | -2.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0255     |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.429       |
# |    value_loss           | 7.95e-07    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 1808       |
# |    iterations           | 192        |
# |    time_elapsed         | 271        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.01813278 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.8       |
# |    explained_variance   | 0.271      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0274    |
# |    n_updates            | 1910       |
# |    policy_gradient_loss | -0.00962   |
# |    std                  | 0.424      |
# |    value_loss           | 2.93e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 1812       |
# |    iterations           | 193        |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 494080     |
# | train/                  |            |
# |    approx_kl            | 0.01878872 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.33       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.029     |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | -0.00934   |
# |    std                  | 0.419      |
# |    value_loss           | 2.39e-09   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1816        |
# |    iterations           | 194         |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 496640      |
# | train/                  |             |
# |    approx_kl            | 0.018148985 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0345     |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00763    |
# |    std                  | 0.418       |
# |    value_loss           | 3.72e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1819        |
# |    iterations           | 195         |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 499200      |
# | train/                  |             |
# |    approx_kl            | 0.017150199 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.032       |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 0.414       |
# |    value_loss           | 3.42e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1823        |
# |    iterations           | 196         |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.019309554 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0205      |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00919    |
# |    std                  | 0.411       |
# |    value_loss           | 2.41e-08    |
# -----------------------------------------
# /opt/anaconda3/envs/rl4aa25-challenge/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:284: UserWarning: Path 'models/ea/ppo/fanciful-universe-1' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# /Users/simon.hirlaender/PycharmProjects/rl4aa25-challenge/src/wrappers/plot_episode.py:122: UserWarning: WARN: Unable to generate episode plot for self.episode_id=60 because the episode was too short.
#   logger.warn(
# /Users/simon.hirlaender/PycharmProjects/rl4aa25-challenge/src/wrappers/log_task_statistics.py:71: UserWarning: WARN: Unable to save episode plot for self.episode_id = 60 because the episode was too short.
#   logger.warn(

# %% [markdown]
# ## Evaluate your agent
#
# The following code snippet loads your trained policy and evaluates it on a number of randomly generated tuning problems. This is the task you actually need to solve for the challenge.

# %%
model_name = config["run_name"]
model_path = Path("models") / "ea" / "ppo" / model_name
model = PPO.load(model_path / "model")
config = load_config(model_path / "config")

evaluate_policy(model, config, write_data=True, seed=42)

# %% [markdown]
# Now the results are loaded, shown to you and a CSV file is generated at `data/csvs/[model_name].csv`. This file is the one you need to submit to the challenge.

# %%
study = Study.load(f"data/{model_name}", name=model_name)

# %%
study.evaluate_challenge()
# Out:
# Final MAE: 2167 μm
# Steps to convergence: 7.0
# Sum of magnet changes: 4.11
# --------------------
# Score: 0.2083

# %% [markdown]
# You may also admire your trained policy in action by running the following code:

# %%
_ = study.episodes[2].plot_summary()

# %% [markdown]
# ## 🏆 Upload your results to Kaggle
#
# For the chance to win the challenge prize. Go to `data/csvs/` and upload the CSV file via \_"Submit Prediction" to the challenge submission page: https://www.kaggle.com/t/ad56a627d147405fa7b5c8629c8b7cf4
